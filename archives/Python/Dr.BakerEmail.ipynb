# %%
#Imports

#Import entire numpy library
from numpy import *

#Import entire cmath library
from cmath import *

#Import scipy.special library
from scipy.special import *

#Import entire pandas library as pd
import pandas as pd

#Import entire matplotlib
import matplotlib as plt

#This is used for variable display in the GUI
import sys

# %%
#===================================================
a = 250 ** (-6) # m

amp = 1 ** (-6) # m

p1 = 1030 # kg/m^3

p2 = 1910 # kg/m^3

f = 500 ** 3 # Hz

w = 2 * pi * f # rad/s

v1 = 1100 # m/s

v2 = 570 # m/s

X1 = 2.4 # dB/MHz/m

X2 = X1 * (v1/v2) # dB/MHz/m

tan1 = ((X1 * v1 * 100) / (pi * (8.686 ** 6)))

tan2 = ((X2 * v2 * 100) / (pi * (8.686 ** 6)))

#===================================================
mu_e = (v2 **2) * p1

mu_v = mu_e * tan2

mu = mu_e + mu_v * 1j

#===================================================
lambda_e = (v1 ** 2) * p1-2 * mu_e

lambda_v = lambda_e * tan1

Lamb = lambda_e + lambda_v * 1j

#===================================================
nu = Lamb / (2 * (Lamb + mu))

a1 = sqrt( (w**2) * p1 / (Lamb + 2 * mu))

b1 = sqrt( p1 * (w**2) / mu) 

#===================================================
phi0 = (amp ** ( 1j * a1 * a * 20)) / a1

#===================================================
